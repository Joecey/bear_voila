# %%
from fastai.vision.widgets import *
from fastai.vision.widgets import *
from fastai.vision.all import * 
import fastbook
fastbook.setup_book()
from fastai.imports import *

# %% [markdown]
# ### Joe's EPIC Bear Classifier
#
#
# Are you stranded in the middle of the woods with a bear like figure is charging at you at full speed and you don't know what you're up against? Well lucky for you, with this bear classfier, you'll know EXACTLY what force of nature you are up against!
#
#
# Disclaimer: This classifier only classifies grizzly, black and teddy bears.

# %%
# MAKE SURE TO UPLOAD UTILS FILE EACH TIME (IT'S IN E:\)
# utils has a bunch of functions that are used throughout the course

# key come from MS Azure bing search api
# this api allows us to download images from the internet, based on given term
key = os.environ.get('AZURE_SEARCH_KEY', 'b9977b83e677493ead5e6258eb65fd8d')

# %%
# Now let's create a model that can differentiate between different bear types
bear_types = 'grizzly', 'black', 'teddy'  
path = Path('bears')

# %%
# if the path "bears" does not exist, create a new one and download images for training 
# otherwise, use folder that is already there 

if not path.exists():
    path.mkdir()

    # for each of the bear types, search bing for that term
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)

        # use bear type + bear
        # create separate directories for each type (150 of each)
        results = search_images_bing(key, f'{o} bear')

        # fast ai function
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
# show all images downloaded 

fns = get_image_files(path)
fns

# check if every file downloaded is an image file
failed = verify_images(fns)
failed

# delete all failed files/non image files
failed.map(Path.unlink)
# Out:
# (#0) []

# %%
class DataLoaders(GetAttr):
    def __init__(self, *loaders): self.loaders = loaders
    train,valid = add_props(lambda i,self: self[i])

# %%
# Create DataBlocks
# ALWAYS RUN THIS INITIAL DATABLOCK FIRST 
bears = DataBlock(
    
    # Image --> input data
    # Category --> labels
    blocks = (ImageBlock, CategoryBlock),

    # get list of files with get_image_files
    get_items=get_image_files,

    # random set for validation uses 30% of data
    splitter = RandomSplitter(valid_pct = 0.3, seed=42),

    # parent_label --> labels each item based on the parent label 
    # e.g. grizzly, black etc 
    get_y = parent_label,       # side note: commas at the end are important

    # tfms = transform
    # Resize(128) --> resize to 128x128 pixel image, having a square image is better (for simplicity)
    # Default is to grab the centre of each image
    # This cropping approach "cuts" information
    
    item_tfms = Resize(128)

)

# Data loader stiches a bunch of images together (usually 64) and sends them 
# to the GPU at once (allows for speed).

# %%
# Now call data loaders
# dls --> variable for our dataloaders
dls = bears.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5), 
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
# From our model from lesson 1

# This is the actual syntax to run the training model

learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)

# this "learn" variable is our model
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.839638</td>
#       <td>0.214726</td>
#       <td>0.090090</td>
#       <td>01:11</td>
#     </tr>
#   </tbody>
# </table>
# G:\LiterallyAnythingElse\anaconda\lib\site-packages\PIL\Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.218249</td>
#       <td>0.096434</td>
#       <td>0.036036</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.147106</td>
#       <td>0.072471</td>
#       <td>0.027027</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.104118</td>
#       <td>0.070658</td>
#       <td>0.027027</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.087651</td>
#       <td>0.063354</td>
#       <td>0.027027</td>
#       <td>01:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
# with our created model "learn", we can now copy this to a server etc
# treat it as a predefined program
learn.export()
path = Path()
path.ls(file_exts = '.pkl')

# our export is called 'export.pkl' be default
# Out:
# (#1) [Path('export.pkl')]

# %%
# Assign path and widgets
path = Path()

learn_inf = load_learner(path/'export.pkl', cpu=True) 
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
# We now create an event handler which executes a function based on what widget is activated
# In this case, when classify button is pressed....

def on_click(change):
    # set img as most recent image
    img = PILImage.create(btn_upload.data[-1])
    
    # clear output widget
    out_pl.clear_output()
    
    # display img in output widget
    with out_pl: display(img.to_thumb(128,128))
     
    # use model to predict what uploaded image is 
    pred,pred_idx,probs = learn_inf.predict(img)
    
    # Replace our label with prediction
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# %%
# Now we create a vertical box (VBox) to complete our GUI
btn_upload.observe(on_click, names = ['data'])

# %%
display(VBox([widgets.Label('Select your bear!'), btn_upload, out_pl, lbl_pred]))
# add upload button, event handler button, output window and label

# It's the exact same buttons, but now we organised them in a "prototpye" application
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Output(), Label(v…

# %%
# install voila
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Requirement already satisfied: voila in g:\literallyanythingelse\anaconda\lib\site-packages (0.2.10)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from voila) (0.5.3)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in g:\literallyanythingelse\anaconda\lib\site-packages (from voila) (6.1.12)
# Requirement already satisfied: nbconvert<7,>=6.0.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from voila) (6.0.7)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from voila) (1.4.1)
# Requirement already satisfied: traitlets in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (5.0.5)
# Requirement already satisfied: jupyter-core>=4.6.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (20.0.0)
# Requirement already satisfied: tornado>=4.1 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<7,>=6.1.3->voila) (227)
# Requirement already satisfied: anyio>=2.0.2 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.2.0)
# Requirement already satisfied: prometheus-client in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.10.1)
# Requirement already satisfied: Send2Trash in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: nbformat in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (5.1.3)
# Requirement already satisfied: ipython-genutils in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.4)
# Requirement already satisfied: jinja2 in g:\literallyanythingelse\anaconda\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.11.3)
# Requirement already satisfied: idna>=2.8 in g:\literallyanythingelse\anaconda\lib\site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Requirement already satisfied: sniffio>=1.1 in g:\literallyanythingelse\anaconda\lib\site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (1.2.0)
# Requirement already satisfied: nest-asyncio in g:\literallyanythingelse\anaconda\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.5.1)
# Requirement already satisfied: async-generator in g:\literallyanythingelse\anaconda\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: testpath in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: pygments>=2.4.1 in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.8.1)
# Requirement already satisfied: jupyterlab-pygments in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.3)
# Requirement already satisfied: bleach in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: defusedxml in g:\literallyanythingelse\anaconda\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in g:\literallyanythingelse\anaconda\lib\site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in g:\literallyanythingelse\anaconda\lib\site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.2.0)
# Requirement already satisfied: setuptools in g:\literallyanythingelse\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (52.0.0.post20210125)
# Requirement already satisfied: attrs>=17.4.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in g:\literallyanythingelse\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.17.3)
# Requirement already satisfied: pywinpty>=0.5 in g:\literallyanythingelse\anaconda\lib\site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.5.7)
# Requirement already satisfied: packaging in g:\literallyanythingelse\anaconda\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.9)
# Requirement already satisfied: webencodings in g:\literallyanythingelse\anaconda\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in g:\literallyanythingelse\anaconda\lib\site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Enabling: voila
# - Writing config: G:\LiterallyAnythingElse\anaconda\etc\jupyter
#     - Validating...
#       voila 0.2.10 ok
